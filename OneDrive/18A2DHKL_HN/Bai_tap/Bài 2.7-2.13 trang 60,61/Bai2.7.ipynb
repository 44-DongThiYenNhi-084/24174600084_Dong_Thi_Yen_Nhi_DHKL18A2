# %%
import json 
data_json= '{"ten":"Dong nhi", "tuoi":19, "lop":"DHKL18A2"}'
python_data= json.loads(data_json)
print(python_data)
print(type(python_data))
# Out:
# {'ten': 'Dong nhi', 'tuoi': 19, 'lop': 'DHKL18A2'}
# <class 'dict'>
