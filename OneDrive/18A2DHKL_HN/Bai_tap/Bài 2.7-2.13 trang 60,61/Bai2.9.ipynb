# %%
import json
sach={
    "ten_sach":" Truyện Doremon",
    "ten_tacgia":"Fujiko F. Fujio",
    "nam_xuatban" : 1969

}
chuoi_json=json.dumps(sach,ensure_ascii=False,indent=4)
print(chuoi_json)
print(type(chuoi_json))
# Out:
# {
#     "ten_sach": " Truyện Doremon",
#     "ten_tacgia": "Fujiko F. Fujio",
#     "nam_xuatban": 1969
# }
# <class 'str'>
